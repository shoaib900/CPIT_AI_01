# %%
import pandas as pd

# %%
df = pd.DataFrame({"name":["asad","asia","adil"],"age":[21,22.5,23] })
print(df)
# Out:
#    name   age
# 0  asad  21.0
# 1  asia  22.5
# 2  adil  23.0

# %%
df["name"]
df["age"]
# Out:
# 0    21.0
# 1    22.5
# 2    23.0
# Name: age, dtype: float64

# %%
df1 = pd.read_csv("Housing.csv")
print(df1)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df1.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df2 = pd.read_csv("Housing1.csv")
print(df2.head())
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0  13300000.0  7420.0         4        2.0        3      yes        no
# 1  12250000.0  8960.0         4        4.0        4      yes       NaN
# 2         NaN  9960.0         3        NaN        2      yes        no
# 3  12215000.0     NaN         4        2.0        2      yes        no
# 4  11410000.0  7420.0         4        1.0        2      yes       yes
#
#   basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0       no              no             yes        2      yes        furnished
# 1       no              no             yes        3       no              NaN
# 2      yes              no              no        2      yes   semi-furnished
# 3      yes              no             yes        3      yes        furnished
# 4      yes              no             yes        2       no        furnished

# %%
df2.dropna(inplace=True)
df2.head()
# Out:
#         price     area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0  13300000.0   7420.0         4        2.0        3      yes        no
# 4  11410000.0   7420.0         4        1.0        2      yes       yes
# 5  10850000.0   7500.0         3        3.0        1      yes        no
# 6  10150000.0   8580.0         4        3.0        4      yes        no
# 7  10150000.0  16200.0         5        3.0        2      yes        no
#
#   basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0       no              no             yes        2      yes        furnished
# 4      yes              no             yes        2       no        furnished
# 5      yes              no             yes        2      yes   semi-furnished
# 6       no              no             yes        2      yes   semi-furnished
# 7       no              no              no        0       no      unfurnished

# %%
df2["price"].head(5)
# Out:
# 0    13300000.0
# 4    11410000.0
# 5    10850000.0
# 6    10150000.0
# 7    10150000.0
# Name: price, dtype: float64

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 542 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             542 non-null    float64
#  1   area              542 non-null    float64
#  2   bedrooms          542 non-null    int64
#  3   bathrooms         542 non-null    float64
#  4   stories           542 non-null    int64
#  5   mainroad          542 non-null    str
#  6   guestroom         542 non-null    str
#  7   basement          542 non-null    str
#  8   hotwaterheating   542 non-null    str
#  9   airconditioning   542 non-null    str
#  10  parking           542 non-null    int64
#  11  prefarea          542 non-null    str
#  12  furnishingstatus  542 non-null    str
# dtypes: float64(3), int64(3), str(7)
# memory usage: 59.3 KB

# %%
df2["price"].head(15)
# Out:
# 0     13300000.0
# 4     11410000.0
# 5     10850000.0
# 6     10150000.0
# 7     10150000.0
# 8      9870000.0
# 9      9800000.0
# 10     9800000.0
# 11     9681000.0
# 12     9310000.0
# 13     9240000.0
# 14     9240000.0
# 15     9100000.0
# 16     9100000.0
# 17     8960000.0
# Name: price, dtype: float64

# %%
df2 = pd.read_csv("Housing.csv", nrows=50)
print(df2)
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000   7420         4          2        3      yes        no       no
# 1   12250000   8960         4          4        4      yes        no       no
# 2   12250000   9960         3          2        2      yes        no      yes
# 3   12215000   7500         4          2        2      yes        no      yes
# 4   11410000   7420         4          1        2      yes       yes      yes
# 5   10850000   7500         3          3        1      yes        no      yes
# 6   10150000   8580         4          3        4      yes        no       no
# 7   10150000  16200         5          3        2      yes        no       no
# 8    9870000   8100         4          1        2      yes       yes      yes
# 9    9800000   5750         3          2        4      yes       yes       no
# 10   9800000  13200         3          1        2      yes        no      yes
# ...

# %%
print(df2["price"].head(5) , df2["bedrooms"].head(5))
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64 0    4
# 1    4
# 2    3
# 3    4
# 4    4
# Name: bedrooms, dtype: int64

# %%
df2.iloc[1]
# Out:
# price                12250000
# area                     8960
# bedrooms                    4
# bathrooms                   4
# stories                     4
# mainroad                  yes
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning           yes
# parking                     3
# prefarea                   no
# furnishingstatus    furnished
# Name: 1, dtype: object

# %%
df2.iloc[100: 110]
# Out:
# Empty DataFrame
# Columns: [price, area, bedrooms, bathrooms, stories, mainroad, guestroom, basement, hotwaterheating, airconditioning, parking, prefarea, furnishingstatus]
# Index: []
